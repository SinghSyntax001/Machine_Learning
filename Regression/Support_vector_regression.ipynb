# %% [markdown]
# # Support Vector Regression (SVR)

# %% [markdown]
# ## Importing the libraries

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# ## Importing the dataset

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
df=pd.read_csv("ENTER_YOUR_DATASET_NAME_HERE.csv")
x=df.iloc[:, 1:-1].values
y=df.iloc[:,-1].values

# %%
print(x)

# %%
print(y)

# %%
y = y.reshape(len(y),1)

# %% [markdown]
# ## Feature Scaling

# %%
from sklearn.preprocessing import StandardScaler
sc_x = StandardScaler()
sc_y = StandardScaler()

x = sc_x.fit_transform(x)
y = sc_y.fit_transform(y)

# %%
print(x)

# %%
print(y)

# %% [markdown]
# ## Training the SVR model on the whole dataset

# %%
from sklearn.svm import SVR
regressor = SVR(kernel='rbf')
regressor.fit(x,y)

# %% [markdown]
# ## Predicting a new result

# %%
sc_y.inverse_transform(regressor.predict(sc_x.transform([[6.5]])).reshape(-1,1)) # to inverse the prediction we scaled above for the salary column
# for interpretibility we used inverse transform to make the scaled  value into original value

# %% [markdown]
# ## Visualising the SVR results

# %%
plt.scatter(sc_x.inverse_transform(x),sc_y.inverse_transform(y),color='red')
plt.plot(sc_x.inverse_transform(x),
         sc_y.inverse_transform(regressor.predict(x).reshape(-1,1)),
         color='blue')
# we already scaled the x by inverse transform so we removed the 6.5 and used the x
plt.title('Truth or Bluff (SVR)')
plt.xlabel('Position level')
plt.ylabel('Salary')
plt.show()

# %% [markdown]
# ## Visualising the SVR results (for higher resolution and smoother curve)

# %%
x_grid = np.arange(min(x), max(x), 0.1)  # Keep it in scaled format
x_grid = x_grid.reshape((len(x_grid), 1))

# Scatter plot (Original data)
plt.scatter(sc_x.inverse_transform(x), sc_y.inverse_transform(y), color='red')


plt.plot(sc_x.inverse_transform(x_grid),
         sc_y.inverse_transform(regressor.predict(x_grid).reshape(-1, 1)),
         color='blue')


plt.title('Truth or Bluff (SVR)')
plt.xlabel('Position Level')
plt.ylabel('Salary')
plt.show()

# %% [markdown]
# ## Evaluating Model's Performance

# %%
from sklearn.metrics import r2_score
r2_score(y_test,y_pred)
